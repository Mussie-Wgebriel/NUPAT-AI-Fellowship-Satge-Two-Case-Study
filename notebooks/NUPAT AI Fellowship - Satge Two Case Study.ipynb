# %%
NUPAT AI Fellowship – Stage Two Case Study
Author: Mussie Weldegebriel

This notebook analyzes user trading and activity data to extract market insights, build a fraud detection model, and propose a data-driven business strategy.

# %%
1. Setup & Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
trades = pd.read_csv('trades.csv')
activity = pd.read_csv('user_activitycsv.csv')

# Convert timestamps to proper datetime objects
trades['timestamp'] = pd.to_datetime(trades['timestamp'])
activity['timestamp'] = pd.to_datetime(activity['timestamp'])

print("Data loaded successfully!")
